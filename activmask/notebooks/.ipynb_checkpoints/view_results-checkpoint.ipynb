# %%
import numpy as np
#import matplotlib
#matplotlib.use('Agg');
import matplotlib.pyplot as plt
#plt.set_cmap('jet');
import random, os, sys, pandas, os, pickle
import argparse
from textwrap import wrap
# %matplotlib inline
import glob

# %%
# Collects all of the results available in logs-single.
ddf = pandas.DataFrame()
for f in glob.glob("../logs-single/*/stats/metrics.pkl"):
    d = (pickle.load(open(f,"rb")))
    ddf = ddf.append(pandas.DataFrame(d), sort=True)
df = ddf.copy()

# Clean out the dataframe.
KEEP = ["auc", "best", "recon_lambda", "actdiff_lambda", "epoch", "name"]
for col in df.columns:
    if not any([string in col for string in KEEP]):
        del df[col]

# Experiment name is determined by the configuration file used.
experiments = df.experiment_name.unique()

print("resulting df \nshape={} tracking {} experiments, \ncolumns={}".format(
    df.shape, len(experiments), df.columns))

# If you want to filter by some condition...
# df = df[(df.nsamples == 64) & (df.optimizer_lr==0.0001)]
# Out:
# resulting df
# shape=(70000, 12) tracking 14 experiments,
# columns=Index(['actdiff_lambda', 'best_epoch', 'best_test_auc', 'best_train_auc',
#        'best_valid_auc', 'epoch', 'experiment_name', 'num_epochs',
#        'recon_lambda', 'test_auc', 'train_auc', 'valid_auc'],
#       dtype='object')

# %%
# Get the available datasets
df_synth = df[df['experiment_name'].str.contains('synth')]
df_liver = df[df['experiment_name'].str.contains('liver')]
# Out:
#                                                           best_epoch  \
# experiment_name        epoch actdiff_lambda recon_lambda
# synth_ae               499   0              10                   0.0
# synth_ae_actdiff       499   10             10                 151.5
# synth_ae_clfmasked     499   0              10                  73.0
# synth_ae_reconmasked   499   0              10                   0.0
# synth_cnn              499   0              0                    0.0
# synth_cnn_actdiff      499   10             0                    7.3
# synth_cnn_clfmasked    499   0              0                    8.3
# synth_resnet           499   0              0                    0.0
# synth_resnet_actdiff   499   10             0                  181.1
# synth_resnet_clfmasked 499   0              0                   40.3
# synth_unet             499   0              10                   0.0
# synth_unet_actdiff     499   10             10                  63.1
# synth_unet_clfmasked   499   0              10                  92.2
# synth_unet_reconmasked 499   0              10                   1.6
#
#                                                           best_test_auc  \
# experiment_name        epoch actdiff_lambda recon_lambda
# synth_ae               499   0              10                 0.500000
# synth_ae_actdiff       499   10             10                 0.829688
# synth_ae_clfmasked     499   0              10                 0.720313
# synth_ae_reconmasked   499   0              10                 0.500000
# synth_cnn              499   0              0                  0.500000
# synth_cnn_actdiff      499   10             0                  0.500000
# synth_cnn_clfmasked    499   0              0                  0.687500
# synth_resnet           499   0              0                  0.500000
# synth_resnet_actdiff   499   10             0                  0.973437
# synth_resnet_clfmasked 499   0              0                  0.917969
# synth_unet             499   0              10                 0.500000
# synth_unet_actdiff     499   10             10                 0.982812
# synth_unet_clfmasked   499   0              10                 0.739844
# synth_unet_reconmasked 499   0              10                 0.503125
#
#                                                           best_train_auc  \
# experiment_name        epoch actdiff_lambda recon_lambda
# synth_ae               499   0              10                    0.5000
# synth_ae_actdiff       499   10             10                    0.8442
# synth_ae_clfmasked     499   0              10                    0.7800
# synth_ae_reconmasked   499   0              10                    0.5000
# synth_cnn              499   0              0                     0.5000
# synth_cnn_actdiff      499   10             0                     0.5024
# synth_cnn_clfmasked    499   0              0                     0.7668
# synth_resnet           499   0              0                     0.5000
# synth_resnet_actdiff   499   10             0                     0.9996
# synth_resnet_clfmasked 499   0              0                     0.8460
# synth_unet             499   0              10                    0.5000
# synth_unet_actdiff     499   10             10                    0.9916
# synth_unet_clfmasked   499   0              10                    0.7676
# synth_unet_reconmasked 499   0              10                    0.5026
#
#                                                           best_valid_auc  \
# experiment_name        epoch actdiff_lambda recon_lambda
# synth_ae               499   0              10                  0.500000
# synth_ae_actdiff       499   10             10                  0.849219
# synth_ae_clfmasked     499   0              10                  0.742969
# synth_ae_reconmasked   499   0              10                  0.500000
# synth_cnn              499   0              0                   0.500000
# synth_cnn_actdiff      499   10             0                   0.500781
# synth_cnn_clfmasked    499   0              0                   0.724219
# synth_resnet           499   0              0                   0.500000
# synth_resnet_actdiff   499   10             0                   1.000000
# synth_resnet_clfmasked 499   0              0                   0.906250
# synth_unet             499   0              10                  0.500000
# synth_unet_actdiff     499   10             10                  1.000000
# synth_unet_clfmasked   499   0              10                  0.755469
# synth_unet_reconmasked 499   0              10                  0.503906
#
#                                                           num_epochs  \
# experiment_name        epoch actdiff_lambda recon_lambda
# synth_ae               499   0              10                 500.0
# synth_ae_actdiff       499   10             10                 500.0
# synth_ae_clfmasked     499   0              10                 500.0
# synth_ae_reconmasked   499   0              10                 500.0
# synth_cnn              499   0              0                  500.0
# synth_cnn_actdiff      499   10             0                  500.0
# synth_cnn_clfmasked    499   0              0                  500.0
# synth_resnet           499   0              0                  500.0
# synth_resnet_actdiff   499   10             0                  500.0
# synth_resnet_clfmasked 499   0              0                  500.0
# synth_unet             499   0              10                 500.0
# synth_unet_actdiff     499   10             10                 500.0
# synth_unet_clfmasked   499   0              10                 500.0
# synth_unet_reconmasked 499   0              10                 500.0
#
#                                                           test_auc  train_auc  \
# experiment_name        epoch actdiff_lambda recon_lambda
# synth_ae               499   0              10            0.500000     1.0000
# synth_ae_actdiff       499   10             10            0.829688     0.8500
# synth_ae_clfmasked     499   0              10            0.720313     0.9998
# synth_ae_reconmasked   499   0              10            0.500000     1.0000
# synth_cnn              499   0              0             0.500000     1.0000
# synth_cnn_actdiff      499   10             0             0.500000     0.5000
# synth_cnn_clfmasked    499   0              0             0.687500     1.0000
# synth_resnet           499   0              0             0.500000     1.0000
# synth_resnet_actdiff   499   10             0             0.973437     1.0000
# synth_resnet_clfmasked 499   0              0             0.917969     0.9998
# synth_unet             499   0              10            0.500000     1.0000
# synth_unet_actdiff     499   10             10            0.982812     1.0000
# synth_unet_clfmasked   499   0              10            0.739844     1.0000
# synth_unet_reconmasked 499   0              10            0.503125     1.0000
#
#                                                           valid_auc
# experiment_name        epoch actdiff_lambda recon_lambda
# synth_ae               499   0              10             0.056250
# synth_ae_actdiff       499   10             10             0.846875
# synth_ae_clfmasked     499   0              10             0.523438
# synth_ae_reconmasked   499   0              10             0.069531
# synth_cnn              499   0              0              0.004687
# synth_cnn_actdiff      499   10             0              0.500000
# synth_cnn_clfmasked    499   0              0              0.541406
# synth_resnet           499   0              0              0.000000
# synth_resnet_actdiff   499   10             0              0.997656
# synth_resnet_clfmasked 499   0              0              0.575781
# synth_unet             499   0              10             0.039844
# synth_unet_actdiff     499   10             10             0.996875
# synth_unet_clfmasked   499   0              10             0.528906
# synth_unet_reconmasked 499   0              10             0.021094

# %%
def get_results(df):
    
    # Plots the valid AUC over epochs for all experiments!
    EPOCH = 499
    EXPERIMENTS = ['unet', 'ae', 'resnet', 'cnn']
    EXP_NAMES = ["UNet", "Autoencoder", "ResNet 18", "ConvNet"]

    df[(df.epoch==EPOCH)].groupby(
        ["experiment_name", "epoch", "actdiff_lambda", "recon_lambda"]).mean()

    for exp, exp_name in zip(EXPERIMENTS, EXP_NAMES):
        fig, ax = plt.subplots(figsize=(8,6))
        ls = ['solid', 'dashed', 'dashdot', 'dotted', '-' ,'--' ,'-.' , ':','None' ,' ' ,'' ]
        dfs = df.reindex()

        # Filter by experiment.
        dfs = dfs[dfs['experiment_name'].str.contains(exp)]

        for i, name in enumerate(sorted(dfs.experiment_name.unique())):
 
            thisdata = dfs[dfs["experiment_name"] == name]
            willplot = thisdata.groupby(["epoch"]).mean()
            r = willplot.plot(y="valid_auc", ax=ax, label=name, ls=ls[i])
            plt.legend(title="experiment")
        plt.ylim(-0.05, 1.05)  
        plt.ylabel("AUC")  
        plt.xlabel("Epoch")

        plt.title("{} Experiments".format(exp_name))

# %%
fig, ax = plt.subplots()
ls = ['solid', 'dashed', 'dashdot', 'dotted', '-' ,'--' ,'-.' , ':','None' ,' ' ,'' ]

subsetdata = df[(df.nsamples == 32) & 
              (df.thing == True) & 
              (df.maskblur == 2) & 
              (df.annealinglambda == 1.0) & 
              (df.dataset == "lung")].reindex()
for k,i in enumerate(sorted(subsetdata.maxmasks.unique())):

    thisdata = subsetdata[subsetdata.maxmasks == i]
    r = thisdata.groupby(["epoch"]).mean().plot(
        y="validauc", ax=ax, label=str(i), ls=ls[k])
    print (i, "num trials", thisdata.groupby(["epoch"]).count().min()[0])
    plt.legend(title="# masks used")
#plt.ylim(.65, 0.81);
plt.xlim(0,500);

plt.title("Vary maxmasks used, nsamples:" + str(thisdata.nsamples.unique()[0]) + 
          ", trials:" + str(thisdata.seed.unique().shape[0]));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-d872b8112777> in <module>()
#       5               (df.thing == True) &
#       6               (df.maskblur == 2) &
# ----> 7               (df.annealinglambda == 1.0) &
#       8               (df.dataset == "lung")].reindex()
#       9 for k,i in enumerate(sorted(subsetdata.maxmasks.unique())):
#
# ~/python/python-37/envs/activmask/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'nsamples'

# %%
df[(df.epoch==99)].groupby(["penalise_grad"])[["best_testauc_for_validauc"]].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-7893361235a6> in <module>()
# ----> 1 df[(df.epoch==99)].groupby(["penalise_grad"])[["best_testauc_for_validauc"]].count()
#
# ~/python/python-37/envs/activmask/lib/python3.5/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/python/python-37/envs/activmask/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ~/python/python-37/envs/activmask/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# ~/python/python-37/envs/activmask/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'penalise_grad'

# %%
qq = df[(df.epoch==99)].groupby(["penalise_grad", "conditional_reg"])[["best_testauc_for_validauc"]]
q = qq.mean().join(qq.std(),rsuffix='_std')
q = q.join(qq.count(),rsuffix='_count')
q
# Out:
#                                best_testauc_for_validauc  \
# penalise_grad conditional_reg
# False         0                                 0.726562
# contrast      1                                 0.710938
# diff_from_ref 1                                 0.648438
#
#                                best_testauc_for_validauc_std  \
# penalise_grad conditional_reg
# False         0                                          NaN
# contrast      1                                          NaN
# diff_from_ref 1                                          NaN
#
#                                best_testauc_for_validauc_count
# penalise_grad conditional_reg
# False         0                                              1
# contrast      1                                              1
# diff_from_ref 1                                              1

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-e5e8532c2ea0> in <module>
# ----> 1 qq.apply[qq['penalise_grad'] == 'diff_from_ref']
#
# ~/miniconda3/envs/gradmask/lib/python3.5/site-packages/pandas/core/base.py in __getitem__(self, key)
#     256         if self._selection is not None:
#     257             raise IndexError('Column(s) {selection} already selected'
# --> 258                              .format(selection=self._selection))
#     259
#     260         if isinstance(key, (list, tuple, ABCSeries, ABCIndexClass,
#
# IndexError: Column(s) ['best_testauc_for_validauc'] already selected

# %%
#subsetdata[subsetdata.penalise_grad == "diff_from_ref"].groupby("seed").count()

# %%
fig, ax = plt.subplots()
ls = ['solid', 'dashed', 'dashdot', 'dotted', '-' ,'--' ,'-.' , ':','None' ,' ' ,'' ]

subsetdata = df.reindex()
for k,i in enumerate(sorted(subsetdata.penalise_grad.unique())):

    thisdata = subsetdata[subsetdata.penalise_grad == i]
    willplot = thisdata.groupby(["epoch"]).mean()
    r = willplot.plot(y="validauc", ax=ax, label=str(i), ls=ls[k])
    print (i, "num trials", thisdata.groupby(["epoch"]).count().min()[0])
    plt.legend(title="gradmask")
#plt.ylim(.5, 0.85);
#plt.xlim(0,500);

plt.title(str(subsetdata.train_dataset.unique()) + ", nsamples:" + str(thisdata.test_dataset_nsamples.unique()[0]) + 
          ", trials:" + str(thisdata.seed.unique().shape[0]));
# Out:
# False num trials 1
# contrast num trials 1
# diff_from_ref num trials 1

# %%
fig, ax = plt.subplots()
ls = ['solid', 'dashed', 'dashdot', 'dotted', '-' ,'--' ,'-.' , ':','None' ,' ' ,'' ]

subsetdata = df[df.penalise_grad=="diff_from_ref"].reindex()
for k,i in enumerate(sorted(subsetdata.conditional_reg.unique())):

    thisdata = subsetdata[subsetdata.conditional_reg == i]
    willplot = thisdata.groupby(["epoch"]).mean()
    r = willplot.plot(y="testauc", ax=ax, label=str(i), ls=ls[k])
    print (i, "num trials", thisdata.groupby(["epoch"]).count().min()[0])
    plt.legend(title="conditional_reg")
#plt.ylim(.5, 0.85);
#plt.xlim(0,500);

plt.title(str(subsetdata.train_dataset.unique()) + ", nsamples:" + str(thisdata.nsamples.unique()[0]) + 
          ", trials:" + str(thisdata.seed.unique().shape[0]));
# Out:
# 0 num trials 1
# 1 num trials 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-514c30e26237> in <module>
#      14
#      15 plt.title(str(subsetdata.train_dataset.unique()) + ", nsamples:" + str(thisdata.nsamples.unique()[0]) +
# ---> 16           ", trials:" + str(thisdata.seed.unique().shape[0]));
#
# ~/miniconda3/envs/gradmask/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'nsamples'

# %%
#"num trials", subsetdata[subsetdata.thing == False].groupby(["epoch"]).count()

# %%
fig, ax = plt.subplots()
ls = ['solid', 'dashed', 'dashdot', 'dotted', '-' ,'--' ,'-.' , ':','None' ,' ' ,'' ]

subsetdata = df[(df.nsamples == 32) & 
              (df.maskblur == 3) & 
              (df.batchsize == 16) & 
              (df.annealinglambda == 1.0) & 
              (df.thingstyle == 1.0) & 
              (df.epoch < 800) &
              (df.dataset == "tnt")].reindex()
for k,i in enumerate(sorted(subsetdata.maxmasks.unique())):

    thisdata = subsetdata[subsetdata.maxmasks == i]
    r = thisdata.groupby(["epoch"]).mean().plot(
        y="validauc", ax=ax, label=str(i), ls=ls[k])
    print (i, "num trials", thisdata.groupby(["epoch"]).count().min()[0])
    plt.legend(title="# masks used")
plt.ylim(.55, 0.81);
#plt.xlim(0,500);

params = subsetdata.drop(["trainloss", "validauc", "seed", "epoch"], axis=1).iloc[0].to_dict()
params = "\n".join(wrap(str(params), 60))
plt.title(str(params) + ", trials:" + str(thisdata.seed.unique().shape[0]));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-402-9cdb89b42f2e> in <module>
#       7               (df.annealinglambda == 1.0) &
#       8               (df.thingstyle == 1.0) &
# ----> 9               (df.epoch < 800) &
#      10               (df.dataset == "tnt")].reindex()
#      11 for k,i in enumerate(sorted(subsetdata.maxmasks.unique())):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'maskblur'

# %%
fig, ax = plt.subplots()
ls = ['solid', 'dashed', 'dashdot', 'dotted', '-' ,'--' ,'-.' , ':','None' ,' ' ,'' ]

subsetdata = df[(df.nsamples == 32) & 
              (df.thing == True) & 
              (df.maskblur == 2) & 
              (df.annealinglambda == 1.0) & 
              (df.dataset == "lung")].reindex()
for k,i in enumerate(sorted(subsetdata.maxmasks.unique())):

    thisdata = subsetdata[subsetdata.maxmasks == i]
    r = thisdata.groupby(["epoch"]).mean().plot(
        y="validauc", ax=ax, label=str(i), ls=ls[k])
    print (i, "num trials", thisdata.groupby(["epoch"]).count().min()[0])
    plt.legend(title="# masks used")
#plt.ylim(.65, 0.81);
plt.xlim(0,500);

plt.title("Vary maxmasks used, nsamples:" + str(thisdata.nsamples.unique()[0]) + 
          ", trials:" + str(thisdata.seed.unique().shape[0]));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-403-d872b8112777> in <module>
#       5               (df.thing == True) &
#       6               (df.maskblur == 2) &
# ----> 7               (df.annealinglambda == 1.0) &
#       8               (df.dataset == "lung")].reindex()
#       9 for k,i in enumerate(sorted(subsetdata.maxmasks.unique())):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'thing'

# %%
fig, ax = plt.subplots()
ls = ['solid', 'dashed', 'dashdot', 'dotted', '-' ,'--' ,'-.' , ':','None' ,' ' ,'' ]

subsetdata = df[(df.nsamples == 64) & 
              (df.thing == True) & 
              (df.maskblur == 3) & 
              (df.maxmasks == 64) & 
              (df.dataset == "lung")].reindex()
for k,i in enumerate(sorted(subsetdata.annealinglambda.unique())):

    thisdata = subsetdata[subsetdata.annealinglambda == i]
    r = thisdata.groupby(["epoch"]).mean().plot(
        y="validauc", ax=ax, label=str(i), ls=ls[k])
    print (i, "num trials", thisdata.groupby(["epoch"]).count().min()[0])
    plt.legend(title="annealinglambda")
#plt.ylim(.65, 0.85);
#plt.xlim(0,600);

plt.title("Vary annealinglambda, nsamples:" + str(thisdata.nsamples.unique()[0]) + 
          ", trials:" + str(thisdata.seed.unique().shape[0]));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-404-17b3c3570512> in <module>
#       5               (df.thing == True) &
#       6               (df.maskblur == 3) &
# ----> 7               (df.maxmasks == 64) &
#       8               (df.dataset == "lung")].reindex()
#       9 for k,i in enumerate(sorted(subsetdata.annealinglambda.unique())):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'thing'
